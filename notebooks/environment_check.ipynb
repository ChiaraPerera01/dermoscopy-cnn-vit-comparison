# %% [markdown]
# # Environment Check

# %% [markdown]
# ## 1. Python & package versions

# %%
import sys, platform
print("Python:", sys.version)
print("Platform:", platform.platform())

packages = ["torch", "torchvision", "timm", "sklearn", "pandas", "numpy",
            "matplotlib", "seaborn", "PIL"]
for pkg in packages:
    try:
        mod = __import__(pkg)
        ver = getattr(mod, "__version__", "unknown")
        print(f"  {pkg:<14} {ver}")
    except ImportError:
        print(f"  {pkg:<14} NOT INSTALLED")

# %% [markdown]
# ## 2. GPU check

# %%
import torch

print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
    props = torch.cuda.get_device_properties(0)
    print(f"Total memory: {props.total_memory / 1024**3:.1f} GB")
    print(f"CUDA capability: {props.major}.{props.minor}")
else:
    print("\nNo GPU visible to PyTorch.")

# %%
# !nvidia-smi

# %% [markdown]
# ## 3. Path check

# %%
from pathlib import Path

PROJECT_ROOT = Path(r"D:\Ravishi\MSc Final Project\skin-lesion-xai")

paths_to_check = {
    "Project root": PROJECT_ROOT,
    "data/raw": PROJECT_ROOT / "data" / "raw",
    "data/processed": PROJECT_ROOT / "data" / "processed",
    "HAM10000 metadata": PROJECT_ROOT / "data" / "raw" / "HAM10000_metadata.csv",
    "models/ (checkpoints)": PROJECT_ROOT / "models",
    "results/": PROJECT_ROOT / "results",
    "notebooks/": PROJECT_ROOT / "notebooks",
}

for name, p in paths_to_check.items():
    status = "OK" if p.exists() else "MISSING"
    print(f"  [{status:<7}] {name:<24} {p}")

# %% [markdown]
# ## 4. Quick tensor + GPU sanity test

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
x = torch.randn(1000, 1000, device=device)
y = x @ x.T
print(f"Computed on: {device}")
print(f"Result shape: {y.shape}, sample value: {y[0,0].item():.4f}")
